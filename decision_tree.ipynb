# %%
print('Simdi hangi esyayi aklinda tuttugunu tahmin edecegim \U0001F914')
print('1. Koltuk', '2. Masa', '3. Televizyon', '4. Buzdolabi', '5. Bulasik makinesi', '6. Camasir makinesi ', '7. Bilgisayar', '8. Firin', sep='\n')
while True:
  sor = input('Aklinda tuttugun esya yukaridaki listede mevcut mu? (yes - no) :').lower().strip()
  if sor == 'yes':
    print('Güzel o zaman tahmin etmeye devam edelim  \U0001F609')
    while True:
        esya = input('Bir beyaz esya mi? (yes - no) : ').lower().strip()
        if esya == 'yes':
            while True:
                esya = input('Mutfakta mi kullaniliyor? (yes - no) : ').lower().strip()
                if esya == 'yes':
                    while True:
                        esya = input('Kapagi var mi? (yes - no) : ').lower().strip()
                        if esya == 'yes':
                            while True:
                                esya = input('Yiyecek sogutmak icin mi kullaniliyor? (yes - no) : ').lower().strip()
                                if esya == 'yes':
                                    print('BUZDOLABI  \N{party popper}')
                                    break
                                elif esya == 'no':
                                    while True:  
                                        esya = input('Yemek pisirmek icin mi kullaniliyor? (yes - no) : ').lower().strip()
                                        if esya == 'yes':
                                            print('FIRIN  \N{party popper}')
                                            break
                                        elif esya == 'no':
                                            print('BULASIK MAKINESI \N{party popper}')
                                            break
                                        else:
                                            print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
                                    break
                                else:
                                    print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
                            break
                        elif esya == 'no':
                            print('Bir daha düsün bence kapagi olmali \U0001F928')
                        else:
                            print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
                    break
                elif esya == 'no':
                    print('CAMASIR MAKINESI  \N{party popper} ')
                    break
                else:
                    print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
            break

        elif esya =='no':
            while True:
                esya = input('Ekrani var mi? (yes - no) : ').lower().strip()
                if esya =='yes':
                    while True:
                        esya = input('Klavyesi var mi? (yes - no) : ').lower().strip()
                        if esya == 'yes':
                            print('BILGISAYAR \N{party popper}')
                            break
                        elif esya == 'no':
                            print('TELEVIZYON \N{party popper}')
                            break
                        else:
                            print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
                    break
                elif esya == 'no':
                    while True:
                        esya = input('Üzerine oturuluyor mu? (yes - no) : ').lower().strip()
                        if esya == 'yes':
                            print('KOLTUK \N{party popper}')
                            break
                        elif esya == 'no':
                            print('MASA \N{party popper}')
                            break
                        else:
                            print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
                    
                    break
                else:
                    print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
            break
        else:
            print('Gecersiz giris... Tahmin edene kadar gitmek yok \N{smiling face with sunglasses}')
    break
  elif sor == 'no':
      print('Hayal gücün cok genis seninle bas edemem \U0001F97A')
      break
  else:
    print('Bu oyunu mecbur oynayacaksin \U0001F921')
# Out:
# Simdi hangi esyayi aklinda tuttugunu tahmin edecegim 🤔
# 1. Koltuk
# 2. Masa
# 3. Televizyon
# 4. Buzdolabi
# 5. Bulasik makinesi
# 6. Camasir makinesi
# 7. Bilgisayar
# 8. Firin
# Aklinda tuttugun esya yukaridaki listede mevcut mu? (yes - no) :asd
# Bu oyunu mecbur oynayacaksin 🤡
# Aklinda tuttugun esya yukaridaki listede mevcut mu? (yes - no) :yes
# Güzel o zaman tahmin etmeye devam edelim  😉
# Bir beyaz esya mi? (yes - no) : asd
# Gecersiz giris... Tahmin edene kadar gitmek yok 😎
# Bir beyaz esya mi? (yes - no) : no
# Ekrani var mi? (yes - no) : no
# Üzerine oturuluyor mu? (yes - no) : sad
# Gecersiz giris... Tahmin edene kadar gitmek yok 😎
# Üzerine oturuluyor mu? (yes - no) : no
# MASA 🎉
